# %%
# programa que lê 2 números e mostra a soma
a = int(input('Digite o 1o número: '))
b = int(input('Digite o 2o número: '))
soma = a + b
print('A soma é {}'.format(soma))
# Out:
# Digite o 1o número:  2
# Digite o 2o número:  6
# A soma é 8

# %%
# Cálculo da área de um triângulo
base_do_triangulo = float(input('Digite a base: '))
altura = float(input('Digite a altura: '))
area = (base*altura)/2
print('A area do triângulo é {}'.format(area))
# Out:
# Digite a base:  1
# Digite a altura:  2
# A area do triângulo é 5.4

# %%
# Cálculo do aumento do salário
salario = float(input('Digite o salário atual: '))
aumento = salario * 0.1
novo_salario = salario + aumento
print('Aumento de R$ {}. Novo salario: R$ {}'.format(aumento, novo_salario))
# Out:
# Digite o salário atual:  30000
# Aumento de R$ 3000.0. Novo salario: R$ 33000.0

# %%
# Média de 3 notas
n1 = float(input('Digite a 1a nota: '))
n2 = float(input('Digite a 2a nota: '))
n3 = float(input('Digite a 3a nota: '))
media = (n1+n2+n3)/3
print('A média das notas é {}'.format(media))
# Out:
# Digite a 1a nota:  20
# Digite a 2a nota:  15
# Digite a 3a nota:  10
# A média das notas é 15.0
