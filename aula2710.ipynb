# %%
print('Alô, mundo!')
# Out:
# Alô, mundo!

# %%
print('Alô, mundo!', 23, "Eu tenho 44 anos.")
# Out:
# Alô, mundo! 23 Eu tenho 44 anos.

# %%
idade = 44

# %%
print(idade)
# Out:
# 44

# %%
print('Eu tenho', idade, 'anos')
# Out:
# Eu tenho 44 anos

# %%
print('Eu tenho {} anos'.format(idade))
# Out:
# Eu tenho 44 anos

# %%
dias = 45

# %%
print('Eu tenho {} anos e faltam {} dias para as férias'.format(idade, dias))
# Out:
# Eu tenho 44 anos e faltam 45 dias para as férias

# %%
idade = input('Digite a sua idade: ')
print('Eu tenho {} anos'.format(idade))
# Out:
# Digite a sua idade:  44
# Eu tenho 44 anos

# %%
print(type(idade))
# Out:
# <class 'str'>

# %%
print(type(dias))
# Out:
# <class 'int'>

# %%
idade = int(idade)

# %%
print(type(idade))
# Out:
# <class 'int'>

# %%
# Programa para calcular o IMC
peso = float(input('Digite o seu peso (Kg): '))
altura = float(input('Digite a sua altura (m): '))
imc = peso/(altura**2)
print('Seu IMC é {}'.format(imc))
# Out:
# Digite o seu peso (Kg):  70.5
# Digite a sua altura (m):  1.71
# Seu IMC é 24.109982558736025

# %%
print(f'Seu IMC é {imc}')
# Out:
# Seu IMC é 24.109982558736025
